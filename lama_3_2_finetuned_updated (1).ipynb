# %% [markdown]
# # Install and update all the necessary Python packages.

# %%
# %%capture
# %pip install -U transformers
# %pip install -U datasets
# %pip install -U accelerate
# %pip install -U peft
# %pip install -U trl
# %pip install -U bitsandbytes
# %pip install -U wandb

# %% [markdown]
# # Load the Python packages and functions we will use throughout the fine-tuning and evaluation process.

# %%
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import (
    LoraConfig,
    PeftModel,
    prepare_model_for_kbit_training,
    get_peft_model,
)
import os, torch, wandb
from datasets import load_dataset
from trl import SFTTrainer, setup_chat_format

# %% [markdown]
# # Hugging Face access token

# %%
read_token='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'
write_token='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'

# read_token='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'
# write_token='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'

# %% [markdown]
# # Install huggingface_hub

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.24.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.8.30)

# %% [markdown]
# # Log in to Hugging Face CLI using the API key.

# %%
# from huggingface_hub import login
# from kaggle_secrets import UserSecretsClient
# user_secrets = UserSecretsClient()

# hf_token = user_secrets.get_secret("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")
# login(token = hf_token)
from huggingface_hub import login
from getpass import getpass

# Prompt the user to enter their Hugging Face token securely
hf_token = getpass("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")

# Log in to Hugging Face using the provided token
login(token=hf_token)
# Out:
# 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··········
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# # Login to Weights & Biases using the API key and instantiate the new project.

# %%
#wb_token = user_secrets.get_secret("wandb")
wandb.login(key='fe579a1e3641448ce3a855814affb7dcb229a7f0')
run = wandb.init(
    project='Fine-tune Llama 3.2 3B on Finance Dataset',
    job_type="training",
    anonymous="allow"
)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: zafor4558 (zafor4558-east-west-university). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/content/wandb/run-20241111_110028-4ys8zo7g</code>
# Syncing run <strong><a href='https://wandb.ai/zafor4558-east-west-university/Fine-tune%20Llama%203.2%203B%20on%20Finance%20Dataset/runs/4ys8zo7g' target="_blank">dulcet-elevator-3</a></strong> to <a href='https://wandb.ai/zafor4558-east-west-university/Fine-tune%20Llama%203.2%203B%20on%20Finance%20Dataset' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/zafor4558-east-west-university/Fine-tune%20Llama%203.2%203B%20on%20Finance%20Dataset' target="_blank">https://wandb.ai/zafor4558-east-west-university/Fine-tune%20Llama%203.2%203B%20on%20Finance%20Dataset</a>
#  View run at <a href='https://wandb.ai/zafor4558-east-west-university/Fine-tune%20Llama%203.2%203B%20on%20Finance%20Dataset/runs/4ys8zo7g' target="_blank">https://wandb.ai/zafor4558-east-west-university/Fine-tune%20Llama%203.2%203B%20on%20Finance%20Dataset/runs/4ys8zo7g</a>

# %% [markdown]
# # Set the variables for base mode, dataset, and new model name. We will be using them in multiple places in this project, so it is better to set them at the start to avoid confusion

# %%
base_model = "BanglaLLM/BanglaLLama-3.2-3b-bangla-alpaca-orca-instruct-v0.0.1"
new_model = "BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1"
dataset_name = "/content/Bangla_FinGpt.xlsx"

# %% [markdown]
# #  Loading the model and tokenizer
# Set the data type and attention implementation.

# %%
# Set torch dtype and attention implementation
if torch.cuda.get_device_capability()[0] >= 8:
    # !pip install -qqq flash-attn
    torch_dtype = torch.bfloat16
    attn_implementation = "flash_attention_2"
else:
    torch_dtype = torch.float16
    attn_implementation = "eager"

# %% [markdown]
# # Load the model and tokenizer by providing the local model directory. Even though our model is small, loading the full model and fine-tuning it will take some time. Instead, we will load the model in 4-bit quantization.

# %%
# QLoRA config
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch_dtype,
    bnb_4bit_use_double_quant=True,
)
# Load model
model = AutoModelForCausalLM.from_pretrained(
    base_model,
    quantization_config=bnb_config,
    device_map="auto",
    attn_implementation=attn_implementation
)

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model, trust_remote_code=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/917 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/21.0k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.25G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/180 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/449 [00:00<?, ?B/s]

# %% [markdown]
# # Loading and processing the dataset

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model)  # Replace "gpt2" with your model as needed

# Load the Excel file using pandas
dataset_name = "/content/Bangla_FinGpt.xlsx"
df = pd.read_excel(dataset_name)

# Convert the pandas DataFrame to a Hugging Face Dataset
dataset = Dataset.from_pandas(df)

# Shuffle and select a subset of the dataset
dataset = dataset.shuffle(seed=65).select(range(1000))

# Define the instruction
instruction = """You are a top-rated Finance AI assistant"""

# Define the chat formatting function
def format_chat_template(row):
    # Manually format the chat conversation
    chat_formatted = f"System: {instruction}\n\nUser: {row['Question']}\n\nAssistant: {row['Answer']}\n\n"
    # Tokenize the formatted chat (if desired)
    row["text"] = chat_formatted
    return row

# Apply the formatting function to the dataset
dataset = dataset.map(
    format_chat_template,
    num_proc=4,
)

# Display a sample to check formatting
print(dataset[4]["text"])
# Out:
# Map (num_proc=4):   0%|          | 0/1000 [00:00<?, ? examples/s]
# System: You are a top-rated Finance AI assistant
#
# User: কোন অবস্থায় ক্রেডিট নোট এবং ডেবিট নোট জারি করতে হয়?
#
# Assistant: "ক্রেডিট নোট" অথবা "ডেবিট নোট" জারি করতে হবে বিধি ২৭ এর বিধান সাপেক্ষে, যদি ইস্যুকৃত এক বা একাধিক কর চালানপত্রে সংশোধনী সংশ্লিষ্ট হয় এবং নিবন্ধিত ব্যক্তি হ্রাসকারী সমন্বয় সাধন করতে চান।

# %%
df.head()
# Out:
#    QuestionID     Type    Topic  \
# 0           1   Bangla  Customs
# 1           2  English  Customs
# 2           3   Bangla  Customs
# 3           4  English  Customs
# 4           5   Bangla  Customs
#
#                                              Context  \
# 0  ১। সংক্ষিপ্ত শিরোনাম ও প্রবর্তন। (১) এই আইন কা...
# 1  1. Short title and introduction. (1) This Act ...
# 2  ১। সংক্ষিপ্ত শিরোনাম ও প্রবর্তন। (১) এই আইন কা...
# 3  1. Short title and introduction. (1) This Act ...
# 4  ১। সংক্ষিপ্ত শিরোনাম ও প্রবর্তন। (১) এই আইন কা...
#
#                                             Question  \
# 0                                        কাস্টমস কি?
# 1                                   What is customs?
# 2   কোন পদে কাস্টমস কর্মকর্তা নিয়োগ প্রদান হতে পারে?
# 3  What positions can be given to the appointment...
# 4                                         দলবিধি কী?
#
#                                               Answer
# 0  কাস্টমস হলো এমন একটি স্থান বা সংস্থা যেখানে বন...
# 1  Customs is a place or organization where autho...
# 2  কাস্টমস কর্মকর্তা নিয়োগ প্রদান হতে পারে কমিশনা...
# 3  The appointment of Customs officers may be Com...
# 4  দলবিধি মূলত একটি আইন, এখানে ইংরেজি হিসেবে "Pen...

# %%
dataset['text'][3]
# Out:
# 'System: You are a top-rated Finance AI assistant\n\nUser: ধারা 163 (5) অনুযায়ী ব্যবসায়িক আয়ের উপর ন্যূনতম কর কত?\n\nAssistant: ধারা 163 (5) অনুযায়ী ব্যবসায়িক আয়ের উপর সর্বনিম্ন কর প্রদত্ত সূত্রের ভিত্তিতে গণনা করা হয়।\n\n'

# %% [markdown]
# # Setting up the model
# Extract the linear model name from the model.

# %%
import bitsandbytes as bnb

def find_all_linear_names(model):
    cls = bnb.nn.Linear4bit
    lora_module_names = set()
    for name, module in model.named_modules():
        if isinstance(module, cls):
            names = name.split('.')
            lora_module_names.add(names[0] if len(names) == 1 else names[-1])
    if 'lm_head' in lora_module_names:  # needed for 16 bit
        lora_module_names.remove('lm_head')
    return list(lora_module_names)

modules = find_all_linear_names(model)

# %% [markdown]
# # Use the linear module name to create the LoRA adopter. We will only fine-tune the LoRA adopter and leave the rest of the model to save memory and for faster training time.

# %%
# LoRA config
peft_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=modules
)
model, tokenizer = setup_chat_format(model, tokenizer)
model = get_peft_model(model, peft_config)
# Out:
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`

# %% [markdown]
# # We are configuring the model hyperparameters to run it

# %%
#Hyperparamter
# training_arguments = TrainingArguments(
#     output_dir=new_model,
#     per_device_train_batch_size=1,
#     per_device_eval_batch_size=1,
#     gradient_accumulation_steps=2,
#     optim="paged_adamw_32bit",
#     num_train_epochs=1,
#     eval_strategy="steps",
#     eval_steps=0.2,
#     logging_steps=1,
#     warmup_steps=10,
#     logging_strategy="steps",
#     learning_rate=2e-4,
#     fp16=False,
#     bf16=False,
#     group_by_length=True,
#     report_to="wandb"
# )

training_arguments = TrainingArguments(
    output_dir=new_model,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    gradient_accumulation_steps=2,
    optim="paged_adamw_32bit",
    num_train_epochs=1,                  # Training for 1 epoch
    eval_strategy="epoch",               # Evaluate at the end of each epoch
    max_steps=-1,                        # No early stopping based on steps
    logging_steps=1,
    warmup_steps=10,
    logging_strategy="steps",
    learning_rate=2e-4,
    fp16=False,
    bf16=False,
    group_by_length=True,
    report_to="wandb"
)

# %% [markdown]
# # We will now set up a supervised fine-tuning (SFT) trainer and provide a train and evaluation dataset, LoRA configuration, training argument, tokenizer, and model.

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into train and test
train_df, test_df = train_test_split(df, test_size=0.1, random_state=42)

# Convert pandas DataFrames to Hugging Face Datasets
train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)

# Ensure each dataset has the formatted text field
train_dataset = train_dataset.map(format_chat_template, num_proc=4)
test_dataset = test_dataset.map(format_chat_template, num_proc=4)

# Now set up the SFTTrainer with the split datasets
trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    peft_config=peft_config,
    max_seq_length=512,
    dataset_text_field="text",
    tokenizer=tokenizer,
    args=training_arguments,
    packing=False,
)
# Out:
# Map (num_proc=4):   0%|          | 0/9370 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/1042 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': max_seq_length, dataset_text_field. Will not be supported from version '0.13.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:300: UserWarning: You passed a `max_seq_length` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:328: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# Map:   0%|          | 0/9370 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1042 [00:00<?, ? examples/s]

# %% [markdown]
# #Model training
# Start the training process and monitor the training and validation loss metrics.

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='4685' max='4685' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4685/4685 1:23:10, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.520400</td>
#       <td>0.977340</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:257: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.
# TrainOutput(global_step=4685, training_loss=1.0484937710435056, metrics={'train_runtime': 4992.3364, 'train_samples_per_second': 1.877, 'train_steps_per_second': 0.938, 'total_flos': 2.779379519106048e+16, 'train_loss': 1.0484937710435056, 'epoch': 1.0})

# %%
wandb.finish()
# Out:
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>▁</td></tr><tr><td>eval/runtime</td><td>▁</td></tr><tr><td>eval/samples_per_second</td><td>▁</td></tr><tr><td>eval/steps_per_second</td><td>▁</td></tr><tr><td>train/epoch</td><td>▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▆▆▆▆▇▇████</td></tr><tr><td>train/global_step</td><td>▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▇████</td></tr><tr><td>train/grad_norm</td><td>▃▅▂▅▆▃▃▅▁▅▅▁▁▅▇▂▂▅▂▄▂▆▆▂▅▅▂▇▂▁▄▄▂▇▆▂▆▆▆█</td></tr><tr><td>train/learning_rate</td><td>█████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▅▅▅▄▄▄▄▃▃▃▃▃▃▂▂▂▂▁</td></tr><tr><td>train/loss</td><td>▂█▂▆▆▂▂▁▆█▂▂▅▇▄▅▂▅▂▅▂▄▇▁▂▆▆▁▂▅▂▆▁▁▆▁▁▂▅▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>0.97734</td></tr><tr><td>eval/runtime</td><td>213.0984</td></tr><tr><td>eval/samples_per_second</td><td>4.89</td></tr><tr><td>eval/steps_per_second</td><td>4.89</td></tr><tr><td>total_flos</td><td>2.779379519106048e+16</td></tr><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/global_step</td><td>4685</td></tr><tr><td>train/grad_norm</td><td>3.34684</td></tr><tr><td>train/learning_rate</td><td>0</td></tr><tr><td>train/loss</td><td>2.5204</td></tr><tr><td>train_loss</td><td>1.04849</td></tr><tr><td>train_runtime</td><td>4992.3364</td></tr><tr><td>train_samples_per_second</td><td>1.877</td></tr><tr><td>train_steps_per_second</td><td>0.938</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dulcet-elevator-3</strong> at: <a href='https://wandb.ai/zafor4558-east-west-university/Fine-tune%20Llama%203.2%203B%20on%20Finance%20Dataset/runs/4ys8zo7g' target="_blank">https://wandb.ai/zafor4558-east-west-university/Fine-tune%20Llama%203.2%203B%20on%20Finance%20Dataset/runs/4ys8zo7g</a><br/> View project at: <a href='https://wandb.ai/zafor4558-east-west-university/Fine-tune%20Llama%203.2%203B%20on%20Finance%20Dataset' target="_blank">https://wandb.ai/zafor4558-east-west-university/Fine-tune%20Llama%203.2%203B%20on%20Finance%20Dataset</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241111_110028-4ys8zo7g/logs</code>

# %%
messages = [{"role": "system", "content": "Please provide a detailed explanation about electronic record storage."},
            {"role": "user", "content": "কীভাবে ইলেকট্রনিক রেকর্ড সংরক্ষণ করা হয়?"}]

prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)

inputs = tokenizer(prompt, return_tensors='pt', padding=True, truncation=True).to("cuda")

outputs = model.generate(**inputs, max_new_tokens=1000, num_return_sequences=1)

text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(text.split("assistant")[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-1a7e7798720c> in <cell line: 4>()
#       2             {"role": "user", "content": "কীভাবে ইলেকট্রনিক রেকর্ড সংরক্ষণ করা হয়?"}]
#       3
# ----> 4 prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
#       5
#       6 inputs = tokenizer(prompt, return_tensors='pt', padding=True, truncation=True).to("cuda")
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in apply_chat_template(self, conversation, tools, documents, chat_template, add_generation_prompt, continue_final_message, tokenize, padding, truncation, max_length, return_tensors, return_dict, return_assistant_tokens_mask, tokenizer_kwargs, **kwargs)
#    1801             tokenizer_kwargs = {}
#    1802
# -> 1803         chat_template = self.get_chat_template(chat_template, tools)
#    1804
#    1805         if return_assistant_tokens_mask and not re.search(r"\{\%-?\s*generation\s*-?\%\}", chat_template):
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in get_chat_template(self, chat_template, tools)
#    1965                 chat_template = self.chat_template
#    1966             else:
# -> 1967                 raise ValueError(
#    1968                     "Cannot use chat template functions because tokenizer.chat_template is not set and no template "
#    1969                     "argument was passed! For information about writing templates and setting the "
#
# ValueError: Cannot use chat template functions because tokenizer.chat_template is not set and no template argument was passed! For information about writing templates and setting the tokenizer.chat_template attribute, please see the documentation at https://huggingface.co/docs/transformers/main/en/chat_templating

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1
# Out:
# /content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1

# %%
# !zip -r /content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1.zip /content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1
# Out:
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/ (stored 0%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2500/ (stored 0%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2500/trainer_state.json (deflated 83%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2500/optimizer.pt (deflated 9%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2500/tokenizer.json (deflated 85%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2500/training_args.bin (deflated 51%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2500/special_tokens_map.json (deflated 66%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2500/tokenizer_config.json (deflated 96%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2500/adapter_config.json (deflated 53%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2500/scheduler.pt (deflated 56%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2500/README.md (deflated 65%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2500/adapter_model.safetensors (deflated 22%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2500/rng_state.pth (deflated 25%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-500/ (stored 0%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-500/trainer_state.json (deflated 82%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-500/optimizer.pt (deflated 9%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-500/tokenizer.json (deflated 85%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-500/training_args.bin (deflated 51%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-500/special_tokens_map.json (deflated 66%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-500/tokenizer_config.json (deflated 96%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-500/adapter_config.json (deflated 53%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-500/scheduler.pt (deflated 56%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-500/README.md (deflated 65%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-500/adapter_model.safetensors (deflated 22%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-500/rng_state.pth (deflated 25%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4500/ (stored 0%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4500/trainer_state.json (deflated 83%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4500/optimizer.pt (deflated 9%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4500/tokenizer.json (deflated 85%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4500/training_args.bin (deflated 51%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4500/special_tokens_map.json (deflated 66%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4500/tokenizer_config.json (deflated 96%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4500/adapter_config.json (deflated 53%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4500/scheduler.pt (deflated 55%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4500/README.md (deflated 65%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4500/adapter_model.safetensors (deflated 22%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4500/rng_state.pth (deflated 25%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2000/ (stored 0%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2000/trainer_state.json (deflated 83%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2000/optimizer.pt (deflated 9%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2000/tokenizer.json (deflated 85%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2000/training_args.bin (deflated 51%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2000/special_tokens_map.json (deflated 66%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2000/tokenizer_config.json (deflated 96%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2000/adapter_config.json (deflated 53%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2000/scheduler.pt (deflated 55%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2000/README.md (deflated 65%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2000/adapter_model.safetensors (deflated 22%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-2000/rng_state.pth (deflated 25%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1500/ (stored 0%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1500/trainer_state.json (deflated 83%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1500/optimizer.pt (deflated 9%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1500/tokenizer.json (deflated 85%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1500/training_args.bin (deflated 51%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1500/special_tokens_map.json (deflated 66%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1500/tokenizer_config.json (deflated 96%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1500/adapter_config.json (deflated 53%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1500/scheduler.pt (deflated 56%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1500/README.md (deflated 65%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1500/adapter_model.safetensors (deflated 22%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1500/rng_state.pth (deflated 25%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4685/ (stored 0%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4685/trainer_state.json (deflated 83%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4685/optimizer.pt (deflated 9%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4685/tokenizer.json (deflated 85%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4685/training_args.bin (deflated 51%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4685/special_tokens_map.json (deflated 66%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4685/tokenizer_config.json (deflated 96%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4685/adapter_config.json (deflated 53%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4685/scheduler.pt (deflated 56%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4685/README.md (deflated 65%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4685/adapter_model.safetensors (deflated 22%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4685/rng_state.pth (deflated 25%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3000/ (stored 0%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3000/trainer_state.json (deflated 83%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3000/optimizer.pt (deflated 9%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3000/tokenizer.json (deflated 85%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3000/training_args.bin (deflated 51%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3000/special_tokens_map.json (deflated 66%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3000/tokenizer_config.json (deflated 96%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3000/adapter_config.json (deflated 53%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3000/scheduler.pt (deflated 55%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3000/README.md (deflated 65%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3000/adapter_model.safetensors (deflated 22%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3000/rng_state.pth (deflated 25%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4000/ (stored 0%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4000/trainer_state.json (deflated 83%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4000/optimizer.pt (deflated 9%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4000/tokenizer.json (deflated 85%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4000/training_args.bin (deflated 51%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4000/special_tokens_map.json (deflated 66%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4000/tokenizer_config.json (deflated 96%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4000/adapter_config.json (deflated 53%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4000/scheduler.pt (deflated 55%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4000/README.md (deflated 65%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4000/adapter_model.safetensors (deflated 22%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-4000/rng_state.pth (deflated 25%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3500/ (stored 0%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3500/trainer_state.json (deflated 83%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3500/optimizer.pt (deflated 9%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3500/tokenizer.json (deflated 85%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3500/training_args.bin (deflated 51%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3500/special_tokens_map.json (deflated 66%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3500/tokenizer_config.json (deflated 96%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3500/adapter_config.json (deflated 53%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3500/scheduler.pt (deflated 55%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3500/README.md (deflated 65%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3500/adapter_model.safetensors (deflated 22%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-3500/rng_state.pth (deflated 25%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1000/ (stored 0%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1000/trainer_state.json (deflated 83%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1000/optimizer.pt (deflated 9%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1000/tokenizer.json (deflated 85%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1000/training_args.bin (deflated 51%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1000/special_tokens_map.json (deflated 66%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1000/tokenizer_config.json (deflated 96%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1000/adapter_config.json (deflated 53%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1000/scheduler.pt (deflated 55%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1000/README.md (deflated 65%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1000/adapter_model.safetensors (deflated 22%)
#   adding: content/BanglaLLama-3.2-3b-banglafingpt_finetuned-instruct-v0.0.1/checkpoint-1000/rng_state.pth (deflated 25%)

# %%
# Save the fine-tuned model
# trainer.model.save_pretrained(new_model)
# trainer.model.push_to_hub(new_model, use_temp_dir=False)

# %%
# # Merge adapter with base model
# base_model_reload, tokenizer = setup_chat_format(base_model_reload, tokenizer)
# # Ensure that 'new_model' points to the correct directory containing the adapter configuration.
# # For example, if your adapter is stored in a subdirectory within 'new_model'
# # called 'adapter_dir', you would modify the path:
# # model = PeftModel.from_pretrained(base_model_reload, f"{new_model}/adapter_dir")
# #
# # If the adapter configuration is directly within 'new_model', the following should work:

# model = PeftModel.from_pretrained(base_model_reload, new_model)

model = model.merge_and_unload()
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora/bnb.py:336: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(

# %%
instruction = """You are a top-rated customer service agent named John.
    Be polite to customers and answer all their questions.
    """

messages = [{"role": "system", "content": instruction},
    {"role": "user", "content": "I have to see what payment payment modalities are accepted"}]

prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)

inputs = tokenizer(prompt, return_tensors='pt', padding=True, truncation=True).to("cuda")

outputs = model.generate(**inputs, max_new_tokens=150, num_return_sequences=1)

text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(text.split("assistant")[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-d219245e9fb5> in <cell line: 8>()
#       6     {"role": "user", "content": "I have to see what payment payment modalities are accepted"}]
#       7
# ----> 8 prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
#       9
#      10 inputs = tokenizer(prompt, return_tensors='pt', padding=True, truncation=True).to("cuda")
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in apply_chat_template(self, conversation, tools, documents, chat_template, add_generation_prompt, continue_final_message, tokenize, padding, truncation, max_length, return_tensors, return_dict, return_assistant_tokens_mask, tokenizer_kwargs, **kwargs)
#    1801             tokenizer_kwargs = {}
#    1802
# -> 1803         chat_template = self.get_chat_template(chat_template, tools)
#    1804
#    1805         if return_assistant_tokens_mask and not re.search(r"\{\%-?\s*generation\s*-?\%\}", chat_template):
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in get_chat_template(self, chat_template, tools)
#    1965                 chat_template = self.chat_template
#    1966             else:
# -> 1967                 raise ValueError(
#    1968                     "Cannot use chat template functions because tokenizer.chat_template is not set and no template "
#    1969                     "argument was passed! For information about writing templates and setting the "
#
# ValueError: Cannot use chat template functions because tokenizer.chat_template is not set and no template argument was passed! For information about writing templates and setting the tokenizer.chat_template attribute, please see the documentation at https://huggingface.co/docs/transformers/main/en/chat_templating

# %%
model.save_pretrained(new_model)
tokenizer.save_pretrained(new_model)

# %%
model.push_to_hub(new_model, use_temp_dir=False)
tokenizer.push_to_hub(new_model, use_temp_dir=False)
